# %% [markdown]
# # Affichage
#
# Ces notions sont abordées en détail ici : <https://python.sdv.u-paris.fr/03_affichage/>
#
# *Exécutez les cellules ci-dessous pour explorer les différentes notions abordées dans ce notebook.*
#
# ## La fonction `print()`
#
# Comme son nom l'indique, cette fonction est utilisée pour afficher quelque chose.
#
# On peut afficher des chaînes de caractères :

# %%
print("Salut Python")

# %% [markdown]
# Des nombres entiers :

# %%
print(42)

# %% [markdown]
# Des nombres réels :

# %%
nombre = 3.14

# %%
print(nombre)

# %% [markdown]
# On peut aussi afficher plusieurs variables. Soit séparémment :

# %%
seq = "ATCTGA" 
nombre_bases = 6

# %%
print(seq)
print(nombre_bases)

# %% [markdown]
# Soit ensemble, en séparant le nom de chaque variable par une virgule :

# %%
print(seq, nombre_bases)

# %% [markdown]
# On peut même alterner des chaînes de caractères avec des noms de variables :

# %%
print("La séquence", seq, "contient", nombre_bases, "bases.")

# %% [markdown]
# ## Écriture formatée (*f-strings*)
#
# L'écriture formatée apporte un contrôle plus fin sur la manière d'afficher les variables.
#
# On utilise une grande chaîne de caractères avec à l'intérieur des variables entre accolades :

# %%
print(f"La séquence {seq} contient {nombre_bases} bases.")

# %% [markdown]
# :::{admonition} Attention
# :class: warning
#
# - au caractère **`f`** (comme *f-strings*) devant la chaîne de caractères (juste avant le premier guillemet)
# - aux noms des variables entre **`{ }`**
#
# ::::

# %% [markdown]
# ### Contrôler le nombre de chiffres affichés après la virgule

# %%
valeur_experimentale = 34.7879783705980890
print(valeur_experimentale)

# %% [markdown]
# Vous l'avez sans doute appris en TP, il n'est pas pertinent d'afficher une valeur numérique avec tous les chiffres après la virgule.
#
# L'écriture formatée permet de limiter le nombre de chiffres après la virgule.

# %% [markdown]
# Avec un seul chiffre après la virgule :

# %%
print(f"{valeur_experimentale:.1f}")

# %% [markdown]
# 📝 Remarques :
#
# - Le symbole `:` sépare le nom de la variable (`valeur_experimentale`) de l'opérateur de formatage (`.1f`).
# - L'opérateur de formatage `.1f` signifie qu'on souhaite afficher un nombre réel (*float* -> `f`) avec un chiffre après la virgule (`.1`)
# - C'est bien un arrondi qui est réalisé ici.
#
# Avec deux chiffres après la virgule :

# %%
print(f"{valeur_experimentale:.2f}")

# %% [markdown]
# Avec trois chiffres après la virgule :

# %%
print(f"{valeur_experimentale:.3f}")

# %% [markdown]
# ## Exercices
#
# ### Convertir un temps d'incubation en heures et minutes
#
# Soit un temps d'incubation de 215 minutes, on souhaite connaitre sa correspondance en heures et minutes.
#
# Avec les opérateurs `//` et `%` et en relisant le notebook précédent (`TP1_1_variables_operations.ipynb`) si besoin, déterminez à combien d'heures et de minutes est équivalent ce temps d'incubation.
#
# Définissez au moins trois variables correspondant au temps d'incubation, au nombre d'heures et au nombre de minutes.
#
# Écrivez votre code dans la cellule ci-dessous.

# %% [markdown]
# :::{admonition} Éléments de réponse
# :class: tip
# :class: dropdown
#
# On peut par exemple définir les variables suivantes :
#
# ```python
# temps_incubation = 215
# heures = temps_incubation // 60
# minutes = temps_incubation % 60
# ```
#
# Ici, `60` représente le nombre de minutes dans une heure. On aurait pu être plus explicite en définissant une 4e variable :
#
# ```python
# temps_incubation = 215
# nombre_minutes_dans_une_heure = 60
# heures = temps_incubation // nombre_minutes_dans_une_heure
# minutes = temps_incubation % nombre_minutes_dans_une_heure
# ```
#
# :::

# %% [markdown]
# Affichez ensuite ce résultat avec une écriture formatée (*f-string*) de la manière suivante :
#
# ```none
# Le temps d'incubation est de XX h et YY min
# ```
#
# avec `XX` et `YY` le nombre d'heures et de minutes que vous aurez obtenues précédemment. Ne renseignez pas les valeurs numériques, utilisez les variables définies précédemment.
#
# Écrivez votre code dans la cellule ci-dessous.

# %% [markdown]
# :::{admonition} Éléments de réponse
# :class: tip
# :class: dropdown
#
# Avec les variables précédentes intégrées directement dans la *f-string* :
#
# ```python
# print(f"Le temps d'incubation est de {heures} h et {minutes} min")
# ```
#
# Résultat :
#
# ```none
# Le temps d'incubation est de 3 h et 35 min
# ```
#
# :::

# %% [markdown]
# ### Découper une séquence d'ADN en codons
#
# En biologie moléculaire, les **codons** sont des groupes de **3 nucléotides**.
#
# En utilisant la même approche que précédemment, déterminez le nombre de codons complets et le nombre de nucléotides restants dans une séquence d'ADN de 50 nucléotides. Utilisez ensuite l'écriture formatée pour afficher le résultat de la manière suivante :
#
# ```none
# Cette séquence est consituée de XX codons et YY nucléotides restants
# ```
#
# avec XX et YY le nombre de codons et de nucléotides restants calculés.

# %% [markdown]
# :::{admonition} Éléments de réponse
# :class: tip
# :class: dropdown
#
# Exemple de code possible :
#
# ```python
# longueur_sequence = 50
# nombre_nucleotides_par_codon = 3
# nombre_codons = longueur_sequence // nombre_nucleotides_par_codon
# nombre_nucleotides_restants = longueur_sequence % nombre_nucleotides_par_codon
#
# print(f"Cette séquence est consituée de {nombre_codons} codons et {nombre_nucleotides_restants} nucléotides restants")
# ```
#
# Résultat :
#
# ```python
# Cette séquence est consituée de 16 codons et 2 nucléotides restants
# ```
#
# Remarque : n'hésitez pas à utiliser des noms de variables qui ont un sens par rapport à votre problème.
#
# :::

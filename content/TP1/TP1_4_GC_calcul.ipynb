# %% [markdown]
# # Calcul de pourcentages de GC et de températures de fusion

# %% [markdown]
# ## Partie 1 : Calcul du %GC
#
# Les objectifs de ce *notebook* sont de :
#
# 1. Déterminer le %GC pour les séquences `AATTTGGGCCCATTACATAC` et `GCGAGGAAGATGTAGGCCGG`.
#
# 2. Afficher la valeur du %GC avec deux chiffres après la virgule, sous la forme :
#     ```none
#     Le pourcentage de GC vaut : xx.xx
#     ```
#
# Pour cela, il faudra, pour chaque séquence :
# - Compter (manuellement) le nombre de bases A, T, C et G.
# - Créer quatre variables pour stocker ces quatre valeurs.
# - Calculer le %GC et stockez le résultat dans une autre variable.
# - Afficher le %GC avec la fonction `print()` et l'écriture formatée.
#
# À chaque étape, n'hésitez pas à comparer vos résultats avec vos voisin.e.s.

# %% [markdown]
# ### Séquence 1
#
# La séquence à analyser est :
#
# `AATTTGGGCCCATTACATAC`
#
# Stockez le nombre des différentes bases dans les variables `nb_A_1`, `nb_T_1`, `nb_C_1` et `nb_G_1` :
#
# (*Dans la cellule de code ci-dessous., remplaçez les `...` par le nombre de bases correspondantes.*)

# %%
nb_A_1 = ...
nb_T_1 = ...
nb_C_1 = ...
nb_G_1 = ...

# %% [markdown]
# Calculez le %GC et stockez-le dans la variable `GC_1` :
#
# (*Réutilisez la formule vue dans le notebook `TP1_3_GC_intro.ipynb` en adaptant les noms des variables.*)
#
# :::{admonition} Attention
# :class: warning
#
# Le caractère `%` ne fait pas partie des caractères autorisés pour écrire un nom de variable en Python.
#
# :::

# %% [markdown]
# Affichez le %GC en respectant le format indiqué plus haut :

# %% [markdown]
# :::{admonition} Éléments de réponse
# :class: tip
# :class: dropdown
#
# ```python
# nb_A_1 = 6
# nb_T_1 = 6
# nb_C_1 = 5
# nb_G_1 = 3
#
# GC_1 = (nb_G_1 + nb_C_1)/(nb_A_1 + nb_T_1 + nb_G_1 + nb_C_1) * 100
#
# print("Le pourcentage de GC vaut : {:.2f}".format(GC_1))
# ```
#
# Réponse attendue :
#
# ```none
# Le pourcentage de GC vaut : 40.00
# ```
#
# :::

# %% [markdown]
# ### Séquence 2
#
# La nouvelle séquence à analyser est :
#
# `GCGAGGAAGATGTAGGCCGG`
#
# Stockez le nombre de bases dans les variables `nb_A_2`, `nb_T_2`, `nb_C_2` et `nb_G_2` :
#
# (*Dans la cellule de code ci-dessous., remplaçez les `...` par le nombre de bases correspondantes.*)

# %%
nb_A_2 = ...
nb_T_2 = ...
nb_C_2 = ...
nb_G_2 = ...

# %% [markdown]
# Calculez le %GC et stockez-le dans la variable `GC_2` :
#
# (*Réutilisez la formule pour la séquence 1 en adaptant les noms des variables.*)

# %% [markdown]
# Affichez le %GC en respectant le format indiqué plus haut :

# %% [markdown]
# :::{admonition} Éléments de réponse
# :class: tip
# :class: dropdown
#
# ```python
# nb_A_2 = 5
# nb_T_2 = 2
# nb_C_2 = 3
# nb_G_2 = 10
#
# GC_2 = (nb_G_2 + nb_C_2)/(nb_A_2 + nb_T_2 + nb_G_2 + nb_C_2) * 100
#
# print(f"Le pourcentage de GC vaut : {GC_2:.2f}")
# ```
#
# Réponse attendue :
#
# ```none
# Le pourcentage de GC vaut : 65.00
# ```
#
# :::

# %% [markdown]
# ## Partie 2 : Calcul de la température de fusion
#
# À partir du %GC, déterminez la température de fusion des deux séquences précédentes.
#
# Affichez la température de fusion avec un chiffre après la virgule, sous la forme :
# ```
# La température de fusion vaut : yy.y °C
# ```
#
# Pour cela, pour chaque séquence :
#
# - Reprenez les variables précédentes qui contiennent le nombre de bases A, T, C et G, ainsi que le %GC.
# - Calculez la température de fusion, *Tm*,  et stockez le résultat dans une nouvelle variable.
# - Affichez la température de fusion avec la fonction `print()` et l'écriture formatée.
#
# À chaque étape, comparez vos résultats avec vos voisin·e·s.

# %% [markdown]
# ### Séquence 1
#
# Calculez la température de fusion `Tm_1` à partir des variables `nb_A_1`, `nb_T_1`, `nb_C_1`, `nb_G_1` et `GC_1` :
#
# (*Réutilisez la formule vue dans le notebook `TP1_3_GC_intro.ipynb` en adaptant les noms des variables.*)

# %% [markdown]
# Affichez la température de fusion en respectant le format indiqué précédemment :

# %% [markdown]
# :::{admonition} Éléments de réponse
# :class: tip
# :class: dropdown
#
# En réutilisant les variables définies précédemment :
#
# ```python
# Tm_1 = 64.9 + 0.41 * GC_1 - 672.4/(nb_A_1 + nb_T_1 + nb_G_1 + nb_C_1)
#
# print(f"La température de fusion vaut : {Tm_1:.1f} °C")
# ```
#
# Réponse attendue :
#
# ```none
# La température de fusion vaut : 47.7 °C
# ```
#
# :::

# %% [markdown]
# ### Séquence 2
#
# Calculez la température de fusion `Tm_2` à partir des variables `nb_A_2`, `nb_T_2`, `nb_C_2`, `nb_G_2` et `GC_2` :

# %% [markdown]
# Affichez la température de fusion en respectant le format indiqué précédemment :

# %% [markdown]
# :::{admonition} Éléments de réponse
# :class: tip
# :class: dropdown
#
# En réutilisant les variables définies précédemment :
#
# ```python
# Tm_2 = 64.9 + 0.41 * GC_2 - 672.4/(nb_A_2 + nb_T_2 + nb_G_2 + nb_C_2)
#
# print(f"La température de fusion vaut : {Tm_2:.1f} °C")
# ```
#
# Réponse attendue :
#
# ```none
# La température de fusion vaut : 57.9 °C
# ```
#
# :::

# %% [markdown]
# ## Analyses

# %% [markdown]
# Les températures de fusion calculées pour les deux séquences vous semblent-elles réalistes compte-tenu de ce que vous connaissez de la phase d'hybridation d'une PCR ?
#
# :::{admonition} Aide
# :class: note
# :class: dropdown
#
# Jetez un oeil au notebook précédent qui détaille les 3 phases d'une PCR.
#
# :::

# %% [markdown]
# *entrez ici votre réponse*

# %% [markdown]
# :::{admonition} Éléments de réponse
# :class: tip
# :class: dropdown
#
# Les températures de fusion calculées sont de 47,7 °C et 57,9 °C.
#
# L'intervalle de température pour la phase d'hybridation proposé dans le notebook précédent est 50 - 60 °C. La seconde température est dans l'intervalle proposé. La première est un peu basse, mais cohérente avec l'intervalle indiqué.
#
# :::

# %% [markdown]
# Comparez les températures de fusions entre elles, puis les %GC et enfin la composition en bases de chaque séquence. Vos observations sont-elles cohérentes ?

# %% [markdown]
# *entrez ici votre réponse*

# %% [markdown]
# :::{admonition} Éléments de réponse
# :class: tip
# :class: dropdown
#
# - La séquence 1 a un %GC de 40 % et une température de fusion de 47,7 °C.
# - La séquence 2 a un %GC de 65 % et une température de fusion de 57,9 °C.
#
# Plus une séquence a de bases G et C (donc un %GC élevé), plus il faut de l'énergie pour rompre les liaisons hydrogènes entre les bases G et C, donc plus la température de fusion est élevée.
#
# :::
